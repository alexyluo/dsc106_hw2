# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
daily = pd.read_csv('daily_sales.csv')

# %%
monthly = pd.read_csv('monthly_sales.csv')

# %%
monthly
# Out:
#    Month, Year    HM-NE   CF-NE   FF-NE    HM-SW   CF-SW   FF-SW    HM-NW  \
# 0       Jan-16  1140955  494802  285238  1124565  468568  281141  1111618
# 1       Feb-16  1175529  489804  293882  1200559  480616  288369  1188037
# 2       Mar-16  1235995  494802  296881  1220454  508522  293148  1151657
# 3       Apr-16  1186592  514593  296648  1213616  485843  291505  1149180
# 4       May-16  1272450  530187  305637  1249686  520702  312421  1187579
# 5       Jun-16  1235025  535597  321358  1213908  505795  303477  1239785
# 6       Jul-16  1284426  535177  321106  1269486  508209  317371  1202069
# 7       Aug-16  1323348  551395  330837  1358134  565889  326218  1283993
# 8       Sep-16  1284426  535177  334213  1268860  528691  330162  1295077
# 9       Oct-16  1280303  555233  333140  1315120  526477  328780  1301675
# 10      Nov-16  1319100  572058  343235  1348519  561883  337129  1276693
# 11      Dec-16  1280303  533459  320075  1306490  523023  313813  1287225
# ...

# %%
sns.lineplot(data=monthly, x='Month, Year', y='HM-NE')

# %%
monthly['Datetime'] = pd.to_datetime(monthly['Month, Year'], format='%b-%y')

# %%
monthly.to_csv('monthly_sales.csv', index = False)

# %%
monthly = pd.read_csv('monthly_sales.csv')

# %%
monthly
# Out:
#    Month, Year    HM-NE   CF-NE   FF-NE    HM-SW   CF-SW   FF-SW    HM-NW  \
# 0       Jan-16  1140955  494802  285238  1124565  468568  281141  1111618
# 1       Feb-16  1175529  489804  293882  1200559  480616  288369  1188037
# 2       Mar-16  1235995  494802  296881  1220454  508522  293148  1151657
# 3       Apr-16  1186592  514593  296648  1213616  485843  291505  1149180
# 4       May-16  1272450  530187  305637  1249686  520702  312421  1187579
# 5       Jun-16  1235025  535597  321358  1213908  505795  303477  1239785
# 6       Jul-16  1284426  535177  321106  1269486  508209  317371  1202069
# 7       Aug-16  1323348  551395  330837  1358134  565889  326218  1283993
# 8       Sep-16  1284426  535177  334213  1268860  528691  330162  1295077
# 9       Oct-16  1280303  555233  333140  1315120  526477  328780  1301675
# 10      Nov-16  1319100  572058  343235  1348519  561883  337129  1276693
# 11      Dec-16  1280303  533459  320075  1306490  523023  313813  1287225
# ...

# %%
monthly['Datetime'] = pd.to_datetime(monthly['Month, Year'], format='%b-%y')

# %%
daily.rename(columns = {'Unnamed: 0': 'Weekday'}, inplace = True)

# %%
daily['Weekday Counts'] = daily.apply(lambda x: sum(daily['Weekday'] == x['Weekday']), 1)

# %%
daily.to_csv('daily_sales.csv', index=False)

# %%
daily[daily['Weekday']=='Sunday']
# Out:
#    Weekday        Day  HM-NE  CF-NE  FF-NE  HM-SW  CF-SW  FF-SW  HM-NW  CF-NW  \
# 2   Sunday   1/3/2016  37007  15103   8397  35494  15987   8683  35369  16591
# 9   Sunday  1/10/2016  36906  16905  10580  39361  14788   7105  35332  15809
# 16  Sunday  1/17/2016  38330  16272   9313  36046  16032   7152  35821  14858
# 23  Sunday  1/24/2016  38460  15743   9887  36372  15520   7722  33234  14814
# 30  Sunday  1/31/2016  36880  15892  11201  36430  14213   8302  33681  16929
#
#     FF-NW  HM-SE  CF-SE  FF-SE   HM-C   CF-C  FF-C  Weekday Counts
# 2    8105  34864  13919   7011  35855  15557  8406               5
# 9    7702  33847  15282   7520  35334  14447  7583               5
# 16   7177  33645  15273   7647  36386  15493  7112               5
# 23   7680  35579  14646   7167  36777  13787  6881               5
# 30   8369  35505  14939   7269  34767  15380  7440               5

# %%
dailog = pd.read_csv('daily_salesog.csv')
